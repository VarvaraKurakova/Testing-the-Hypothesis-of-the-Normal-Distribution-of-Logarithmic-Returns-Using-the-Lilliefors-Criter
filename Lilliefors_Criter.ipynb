# %%
import IPython
import os
import pandas as pd
import math
from matplotlib import pyplot as plt
import numpy as np
from numpy import linspace
import scipy.stats as stats
from scipy.stats import norm
import statistics
from scipy.stats import kurtosis
import numpy as np

from math import *

import time

import matplotlib.pyplot as plt

from scipy.stats import norm, scoreatpercentile, kstest, uniform, kstwobign

import pandas as pd

import mpmath as mp

from statsmodels.distributions.empirical_distribution import ECDF

# %%
TickersName = ['MMC','AON','CB','K','CAG','HSY','MKC','AJG','HRL','CPB']

Tickers = range(1,len(TickerName)+1)

TickerName = pd.DataFrame(index = Tickers)

TickerName["Компания"] = TickersName
TickerName
# Out:
#    Компания
# 1       MMC
# 2       AON
# 3        CB
# 4         K
# 5       CAG
# 6       HSY
# 7       MKC
# 8       AJG
# 9       HRL
# 10      CPB

# %%
index = range(1,len(TickersName)+1)
Tickers = ['MMC','AON','CB','K','CAG','HSY','MKC','AJG','HRL','CPB']
TickersName = ['Marsh & McLennan Companies Inc.','Aon plc','Chubb Limited','Kellogg Company','Conagra Brands Inc.',
'Hershey Company' , 'McCormick&Company Incorporated','Arthur J. Gallagher & Co.',
'Hormel Foods Corporation','Campbell Soup Company']

data = {'Тикеры': Tickers, 'Компании': TickersName}
df = pd.DataFrame(data)
print (df)
# Out:
#   Тикеры                         Компании
# 0    MMC  Marsh & McLennan Companies Inc.
# 1    AON                          Aon plc
# 2     CB                    Chubb Limited
# 3      K                  Kellogg Company
# 4    CAG              Conagra Brands Inc.
# 5    HSY                  Hershey Company
# 6    MKC   McCormick&Company Incorporated
# 7    AJG        Arthur J. Gallagher & Co.
# 8    HRL         Hormel Foods Corporation
# 9    CPB            Campbell Soup Company

# %%
MMC_df = pd.read_csv('MMC.csv')
AON_df = pd.read_csv('AON.csv')
CB_df = pd.read_csv('CB.csv')
K_df = pd.read_csv('K.csv')
CAG_df = pd.read_csv('CAG.csv')
HSY_df = pd.read_csv('HSY.csv')
MKC_df = pd.read_csv('MKC.csv')
AJG_df = pd.read_csv('AJG.csv')
HRL_df = pd.read_csv('HRL.csv')
CPB_df = pd.read_csv('CPB.csv')
shares = pd.concat([MMC_df, AON_df, CB_df, K_df, CAG_df, HSY_df, MKC_df, AJG_df, HRL_df, CPB_df])
shares['<DATE>'] = pd.to_datetime(shares['<DATE>'], format='%Y%m%d').dt.year
shares.pivot_table(index='<TICKER>', columns='<DATE>', values='<OPEN>', aggfunc='count')
# Out:
# <DATE>    2012.0  2013.0  2014.0  2015.0  2016.0  2017.0  2018.0  2019.0  \
# <TICKER>
# AJG          186     252     252     252     252     251     251     252
# AON          186     252     252     252     252     251     251     252
# CAG          186     252     252     252     252     251     251     252
# CPB          186     252     252     252     252     251     251     252
# HRL          186     252     252     252     252     251     251     252
# HSY          186     252     252     252     252     251     251     252
# K            186     252     252     252     252     251     251     252
# MKC          186     252     252     252     252     251     251     252
# MMC          186     252     252     252     252     251     251     252
#
# <DATE>    2020.0  2021.0
# <TICKER>
# AJG          253      63
# AON          253      63
# CAG          253      63
# CPB          253      63
# HRL          252      63
# HSY          253      63
# K            253      63
# ...

# %%
tick = ['MMC','AON','CB','K','CAG','HSY','MKC','AJG','HRL','CPB']
df = pd.DataFrame(data)
dfs = [MMC_df, AON_df, CB_df, K_df, CAG_df, HSY_df, MKC_df, AJG_df, HRL_df, CPB_df]
torg_days = pd.DataFrame(index = ['MMC','AON','CB','K','CAG','HSY','MKC','AJG','HRL','CPB'], columns = range(2012,2021))

for x in range(2012,2021): #Заполнение таблицы торговых дней

    for i in range(10):

        torg_days[x][i] = len(dfs[i]['Date'][dfs[i].Date.str.contains(str(x))])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\12121\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-e895f1a61670> in <module>
#       8     for i in range(10):
#       9
# ...

# %%
pd.DataFrame({'Название компании': ['Marsh & McLennan Companies Inc.','Aon plc','Chubb Limited','Kellogg Company','Conagra Brands Inc.',
'Hershey Company' , 'McCormick&Company Incorporated','Arthur J. Gallagher & Co.',
'Hormel Foods Corporation','Campbell Soup Company'],

'Тикер': ['MMC','AON','CB','K','CAG','HSY','MKC','AJG','HRL','CPB']})
# Out:
#                  Название компании Тикер
# 0  Marsh & McLennan Companies Inc.   MMC
# 1                          Aon plc   AON
# 2                    Chubb Limited    CB
# 3                  Kellogg Company     K
# 4              Conagra Brands Inc.   CAG
# 5                  Hershey Company   HSY
# 6   McCormick&Company Incorporated   MKC
# 7        Arthur J. Gallagher & Co.   AJG
# 8         Hormel Foods Corporation   HRL
# 9            Campbell Soup Company   CPB

# %%
pd.DataFrame({'Поле': ['<Date>','<Open>','<High>','<Low>','<Close>','<Adj close>', '<Volume>'],

'Значение': ['Дата','Цена открытия актива','Максимальная цена за период',

'Минимальная цена за период','Цена закрытия актива',

'Скорректированная цена закрытия', 'Объем торгов за период']})
# Out:
#           Поле                         Значение
# 0       <Date>                             Дата
# 1       <Open>             Цена открытия актива
# 2       <High>      Максимальная цена за период
# 3        <Low>       Минимальная цена за период
# 4      <Close>             Цена закрытия актива
# 5  <Adj close>  Скорректированная цена закрытия
# 6     <Volume>           Объем торгов за период

# %%
tick = ['MMC','AON','CB','K','CAG','HSY','MKC','AJG','HRL','CPB']

dfs = [MMC_df, AON_df, CB_df, K_df, CAG_df, HSY_df, MKC_df, AJG_df, HRL_df, CPB_df]
dfs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6440e955a21a> in <module>
#       1 tick = ['MMC','AON','CB','K','CAG','HSY','MKC','AJG','HRL','CPB']
#       2
# ----> 3 dfs = [MMC_df, AON_df, CB_df, K_df, CAG_df, HSY_df, MKC_df, AJG_df, HRL_df, CPB_df]
#       4 dfs
#
# NameError: name 'MMC_df' is not defined

# %%
torg_days = pd.DataFrame(index = ['MMC','AON','CB','K','CAG','HSY','MKC','AJG','HRL','CPB'], columns = range(2012,2022))

for x in range(2012,2022): #Заполнение таблицы торговых дней 
    for i in range(10):
        torg_days[x][i] = len(dfs[i]['Date'][dfs[i].Date.str.contains(str(x))])
del torg_days[2021]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\12121\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-d116aa246ed1> in <module>
# ...
